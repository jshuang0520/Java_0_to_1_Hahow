# %% [markdown]
# ![img1](attachment:image.png)

# %% [markdown]
# ![img4](https://chercher.tech/images/selenium/exception-architechture-java.png)

# %% [markdown]
# [Difference between error and exception in java](http://www.instanceofjava.com/2015/08/difference-between-error-and-exception-java-example-program.html)
#
# ![img3](https://3.bp.blogspot.com/-3rMBRaMlfSc/Vc8L5d0M1cI/AAAAAAAAAcE/tqCAMXrlKh0/s1600/Error%2Bvs%2BException.png)

# %% [markdown]
# [JAVA異常架構圖及常見面試題](https://www.itread01.com/content/1505487494.html)
#
# ![img2](https://images2015.cnblogs.com/blog/774472/201510/774472-20151023222335692-253551304.png)

# %% [markdown]
# ![img5](https://i.stack.imgur.com/upyMt.jpg)
